# %%
import torch
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForCausalLM
from tqdm import tqdm
import nltk
nltk.download("wordnet")
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
from rapidfuzz import fuzz

from huggingface_hub import login

login(token="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")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !pip install rapidfuzz
# !pip install fuzzywuzzy

# %%
kb_df = pd.read_csv("./unique_diseases_with_NHS.csv", encoding='latin1')
kb_df["entry_text"] = kb_df.apply(
    lambda row: f"Disease: {row['Disease']}. Symptoms: {row['Symptoms']}. Guidelines: {row['Guidelines']}.",
    axis=1
)
corpus = kb_df["entry_text"].tolist()

embedder = SentenceTransformer("multi-qa-mpnet-base-dot-v1")
corpus_embeddings = embedder.encode(corpus, convert_to_numpy=True)

embedding_dim = corpus_embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(corpus_embeddings)

# %%
test_df = pd.read_csv("./Final_Prompt-Style_Test_Set_V2.csv")
prompts = test_df["prompt"].tolist()

def retrieve_knowledge(query, top_k=3):
    query_embedding = embedder.encode([query], convert_to_numpy=True)
    distances, indices = index.search(np.array(query_embedding).astype('float32'), top_k)
    return [corpus[idx] for idx in indices[0]]

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel, PeftConfig

# model_path = "./lora_llama_medical_finetuned"

# tokenizer = AutoTokenizer.from_pretrained(model_path)
# model = AutoModelForCausalLM.from_pretrained(
#     model_path,
#     torch_dtype=torch.float16,
#     device_map="auto"
# )

MODEL_NAME = "meta-llama/Llama-3.1-8B-Instruct"

ADAPTER_PATH = "./lora_llama_medical_finetuned"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,
    device_map="auto"
)

model = PeftModel.from_pretrained(base_model, ADAPTER_PATH)
model.eval()

def generate_answer(prompt):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=200,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            eos_token_id=tokenizer.eos_token_id
        )
    return tokenizer.decode(output_ids[0], skip_special_tokens=True)

def extract_answer(output_text):
    if "Doctor:" in output_text:
        return output_text.split("Doctor:")[-1].strip()
    elif "Output:" in output_text:
        return output_text.split("Output:")[-1].strip()
    else:
        return output_text.strip()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /opt/conda/lib/python3.11/site-packages/peft/utils/save_and_load.py:198: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   adapters_weights = torch.load(filename, map_location=torch.device(device))

# %%
results = []
for i, row in tqdm(test_df.iterrows(), total=len(test_df)):
    user_input = row["prompt"]
    ground_truth = row["diagnosis"]

    retrieved = retrieve_knowledge(user_input, top_k=3)
    rag_context = "\n".join(retrieved)

    full_prompt = f"""{rag_context}\nInstruction: {user_input}\nDoctor:"""
    generated_output = generate_answer(full_prompt)
    extracted = extract_answer(generated_output)

    results.append({
        "prompt": user_input,
        "ground_truth": ground_truth,
        "retrieved_knowledge": rag_context,
        "generated_output": generated_output,
        "extracted_diagnosis": extracted
    })

result_df = pd.DataFrame(results)
result_df.to_csv("RAG_diagnosis_predictions_V2.csv", index=False)
print("结果已保存到 RAG_diagnosis_predictions_V2.csv")
# Out:
#   0%|          | 0/984 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   0%|          | 1/984 [00:08<2:13:02,  8.12s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   0%|          | 2/984 [00:15<2:04:19,  7.60s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   0%|          | 3/984 [00:22<2:02:56,  7.52s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   0%|          | 4/984 [00:30<2:00:56,  7.40s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 5/984 [00:37<1:59:37,  7.33s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 6/984 [00:44<1:59:01,  7.30s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 7/984 [00:51<1:58:16,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 8/984 [00:58<1:57:58,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 9/984 [01:06<1:57:33,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 10/984 [01:13<1:57:18,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 11/984 [01:20<1:56:56,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|          | 12/984 [01:27<1:56:28,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|▏         | 13/984 [01:34<1:56:15,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   1%|▏         | 14/984 [01:41<1:56:01,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 15/984 [01:49<1:55:57,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 16/984 [01:56<1:55:43,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 17/984 [02:03<1:55:31,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 18/984 [02:10<1:55:23,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 19/984 [02:17<1:55:26,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 20/984 [02:24<1:55:11,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 21/984 [02:32<1:54:58,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 22/984 [02:39<1:55:03,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 23/984 [02:46<1:54:51,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   2%|▏         | 24/984 [02:53<1:54:31,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 25/984 [03:00<1:54:25,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 26/984 [03:07<1:54:12,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 27/984 [03:15<1:54:22,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 28/984 [03:22<1:54:13,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 29/984 [03:29<1:54:08,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 30/984 [03:36<1:53:55,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 31/984 [03:43<1:53:56,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 32/984 [03:50<1:53:59,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 33/984 [03:58<1:53:40,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   3%|▎         | 34/984 [04:05<1:53:26,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▎         | 35/984 [04:12<1:53:27,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▎         | 36/984 [04:19<1:53:20,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 37/984 [04:26<1:53:12,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 38/984 [04:33<1:53:00,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 39/984 [04:41<1:53:00,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 40/984 [04:48<1:54:20,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 41/984 [04:55<1:54:21,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 42/984 [05:03<1:53:38,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 43/984 [05:10<1:53:37,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   4%|▍         | 44/984 [05:17<1:53:18,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▍         | 45/984 [05:24<1:52:53,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▍         | 46/984 [05:31<1:52:25,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▍         | 47/984 [05:39<1:52:03,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▍         | 48/984 [05:46<1:51:50,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▍         | 49/984 [05:53<1:51:34,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▌         | 50/984 [06:00<1:51:20,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▌         | 51/984 [06:07<1:51:09,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▌         | 52/984 [06:14<1:51:08,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▌         | 53/984 [06:21<1:51:04,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   5%|▌         | 54/984 [06:29<1:50:56,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 55/984 [06:36<1:50:48,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 56/984 [06:43<1:50:46,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 57/984 [06:50<1:50:51,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 58/984 [06:57<1:50:51,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 59/984 [07:04<1:50:49,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 60/984 [07:12<1:50:35,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▌         | 61/984 [07:19<1:50:31,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▋         | 62/984 [07:26<1:50:38,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   6%|▋         | 63/984 [07:33<1:50:34,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 64/984 [07:41<1:50:30,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 65/984 [07:48<1:50:19,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 66/984 [07:55<1:50:26,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 67/984 [08:02<1:50:09,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 68/984 [08:09<1:49:54,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 69/984 [08:17<1:50:16,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 70/984 [08:24<1:50:07,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 71/984 [08:31<1:49:49,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 72/984 [08:38<1:49:38,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   7%|▋         | 73/984 [08:45<1:49:31,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 74/984 [08:53<1:49:37,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 75/984 [09:00<1:49:41,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 76/984 [09:07<1:49:26,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 77/984 [09:14<1:49:07,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 78/984 [09:22<1:48:51,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 79/984 [09:29<1:48:35,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 80/984 [09:36<1:48:46,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 81/984 [09:43<1:48:50,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 82/984 [09:51<1:48:42,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   8%|▊         | 83/984 [09:58<1:48:29,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▊         | 84/984 [10:05<1:48:09,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▊         | 85/984 [10:12<1:47:53,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▊         | 86/984 [10:19<1:47:40,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 87/984 [10:27<1:47:50,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 88/984 [10:34<1:47:32,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 89/984 [10:41<1:47:18,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 90/984 [10:48<1:46:56,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 91/984 [10:55<1:46:39,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 92/984 [11:02<1:46:24,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#   9%|▉         | 93/984 [11:09<1:46:09,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|▉         | 94/984 [11:17<1:46:29,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|▉         | 95/984 [11:24<1:46:12,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|▉         | 96/984 [11:31<1:45:57,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|▉         | 97/984 [11:38<1:45:59,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|▉         | 98/984 [11:45<1:45:51,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|█         | 99/984 [11:53<1:45:51,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|█         | 100/984 [12:00<1:46:12,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|█         | 101/984 [12:07<1:45:50,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|█         | 102/984 [12:14<1:45:55,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  10%|█         | 103/984 [12:21<1:45:37,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 104/984 [12:29<1:45:26,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 105/984 [12:36<1:45:11,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 106/984 [12:43<1:45:12,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 107/984 [12:50<1:45:12,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 108/984 [12:57<1:44:55,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 109/984 [13:04<1:44:47,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█         | 110/984 [13:12<1:44:59,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█▏        | 111/984 [13:19<1:44:50,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█▏        | 112/984 [13:26<1:44:30,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  11%|█▏        | 113/984 [13:33<1:44:31,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 114/984 [13:41<1:44:29,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 115/984 [13:48<1:44:43,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 116/984 [13:55<1:44:17,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 117/984 [14:02<1:43:55,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 118/984 [14:09<1:43:38,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 119/984 [14:16<1:43:30,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 120/984 [14:24<1:43:16,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 121/984 [14:31<1:43:11,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▏        | 122/984 [14:38<1:42:54,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  12%|█▎        | 123/984 [14:45<1:43:27,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 124/984 [14:52<1:43:19,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 125/984 [15:00<1:43:10,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 126/984 [15:07<1:43:10,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 127/984 [15:14<1:43:07,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 128/984 [15:21<1:42:58,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 129/984 [15:29<1:42:50,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 130/984 [15:36<1:42:50,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 131/984 [15:43<1:42:43,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  13%|█▎        | 132/984 [15:50<1:42:12,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▎        | 133/984 [15:57<1:41:58,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▎        | 134/984 [16:04<1:41:37,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▎        | 135/984 [16:12<1:41:25,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 136/984 [16:19<1:41:11,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 137/984 [16:26<1:41:01,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 138/984 [16:33<1:41:01,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 139/984 [16:40<1:40:53,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 140/984 [16:47<1:40:47,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 141/984 [16:55<1:40:41,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  14%|█▍        | 142/984 [17:02<1:40:41,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▍        | 143/984 [17:09<1:40:34,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▍        | 144/984 [17:16<1:40:27,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▍        | 145/984 [17:23<1:40:08,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▍        | 146/984 [17:30<1:39:57,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▍        | 147/984 [17:38<1:39:45,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▌        | 148/984 [17:45<1:39:41,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▌        | 149/984 [17:52<1:39:34,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▌        | 150/984 [17:59<1:39:29,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▌        | 151/984 [18:06<1:39:50,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  15%|█▌        | 152/984 [18:14<1:40:58,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 153/984 [18:21<1:40:56,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 154/984 [18:28<1:40:21,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 155/984 [18:35<1:40:02,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 156/984 [18:43<1:40:11,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 157/984 [18:50<1:40:07,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 158/984 [18:57<1:39:41,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▌        | 159/984 [19:04<1:39:10,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▋        | 160/984 [19:12<1:38:57,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▋        | 161/984 [19:19<1:38:44,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  16%|█▋        | 162/984 [19:26<1:38:39,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 163/984 [19:33<1:38:52,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 164/984 [19:40<1:38:31,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 165/984 [19:48<1:38:09,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 166/984 [19:55<1:38:05,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 167/984 [20:02<1:38:04,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 168/984 [20:09<1:38:17,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 169/984 [20:16<1:38:03,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 170/984 [20:24<1:38:08,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 171/984 [20:31<1:37:38,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  17%|█▋        | 172/984 [20:38<1:37:49,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 173/984 [20:45<1:37:44,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 174/984 [20:53<1:37:17,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 175/984 [21:00<1:36:55,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 176/984 [21:07<1:37:04,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 177/984 [21:14<1:36:48,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 178/984 [21:21<1:36:27,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 179/984 [21:28<1:36:09,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 180/984 [21:36<1:35:53,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 181/984 [21:43<1:35:46,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  18%|█▊        | 182/984 [21:50<1:35:40,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▊        | 183/984 [21:57<1:35:37,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▊        | 184/984 [22:04<1:35:24,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 185/984 [22:11<1:35:40,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 186/984 [22:19<1:35:53,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 187/984 [22:26<1:35:30,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 188/984 [22:33<1:35:14,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 189/984 [22:40<1:35:01,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 190/984 [22:47<1:34:47,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  19%|█▉        | 191/984 [22:54<1:34:37,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|█▉        | 192/984 [23:02<1:34:25,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|█▉        | 193/984 [23:09<1:34:16,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|█▉        | 194/984 [23:16<1:34:16,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|█▉        | 195/984 [23:23<1:34:08,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|█▉        | 196/984 [23:30<1:34:01,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|██        | 197/984 [23:37<1:34:23,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|██        | 198/984 [23:45<1:34:09,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|██        | 199/984 [23:52<1:34:07,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|██        | 200/984 [23:59<1:33:56,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  20%|██        | 201/984 [24:06<1:33:37,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 202/984 [24:13<1:33:32,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 203/984 [24:21<1:33:34,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 204/984 [24:28<1:33:29,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 205/984 [24:35<1:33:11,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 206/984 [24:42<1:32:58,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 207/984 [24:49<1:33:00,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 208/984 [24:57<1:33:31,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██        | 209/984 [25:04<1:33:14,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██▏       | 210/984 [25:11<1:33:00,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  21%|██▏       | 211/984 [25:18<1:33:21,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 212/984 [25:26<1:33:30,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 213/984 [25:33<1:33:00,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 214/984 [25:40<1:32:34,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 215/984 [25:47<1:32:43,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 216/984 [25:54<1:32:30,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 217/984 [26:02<1:32:14,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 218/984 [26:09<1:31:48,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 219/984 [26:16<1:31:34,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 220/984 [26:23<1:31:17,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  22%|██▏       | 221/984 [26:30<1:31:06,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 222/984 [26:38<1:31:17,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 223/984 [26:45<1:31:04,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 224/984 [26:52<1:30:52,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 225/984 [26:59<1:30:48,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 226/984 [27:06<1:30:44,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 227/984 [27:13<1:30:46,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 228/984 [27:21<1:30:38,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 229/984 [27:28<1:30:34,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 230/984 [27:35<1:30:19,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  23%|██▎       | 231/984 [27:42<1:30:17,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▎       | 232/984 [27:49<1:30:06,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▎       | 233/984 [27:57<1:29:52,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 234/984 [28:04<1:29:37,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 235/984 [28:11<1:29:46,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 236/984 [28:18<1:29:52,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 237/984 [28:25<1:29:49,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 238/984 [28:33<1:30:03,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 239/984 [28:40<1:30:03,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 240/984 [28:47<1:29:53,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  24%|██▍       | 241/984 [28:54<1:29:31,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▍       | 242/984 [29:02<1:29:18,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▍       | 243/984 [29:09<1:29:03,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▍       | 244/984 [29:16<1:29:00,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▍       | 245/984 [29:23<1:28:46,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▌       | 246/984 [29:30<1:28:46,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▌       | 247/984 [29:38<1:28:56,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▌       | 248/984 [29:45<1:29:01,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▌       | 249/984 [29:52<1:29:19,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  25%|██▌       | 250/984 [30:00<1:28:44,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 251/984 [30:07<1:28:14,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 252/984 [30:14<1:27:57,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 253/984 [30:21<1:27:43,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 254/984 [30:28<1:27:31,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 255/984 [30:35<1:27:19,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 256/984 [30:43<1:27:12,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 257/984 [30:50<1:27:02,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▌       | 258/984 [30:57<1:26:48,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▋       | 259/984 [31:04<1:26:45,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  26%|██▋       | 260/984 [31:11<1:26:44,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 261/984 [31:19<1:26:30,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 262/984 [31:26<1:26:22,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 263/984 [31:33<1:26:12,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 264/984 [31:40<1:26:04,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 265/984 [31:47<1:26:10,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 266/984 [31:54<1:25:57,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 267/984 [32:02<1:26:16,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 268/984 [32:09<1:25:54,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 269/984 [32:16<1:26:11,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  27%|██▋       | 270/984 [32:23<1:26:00,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 271/984 [32:31<1:25:41,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 272/984 [32:38<1:25:15,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 273/984 [32:45<1:25:03,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 274/984 [32:52<1:25:09,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 275/984 [32:59<1:24:58,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 276/984 [33:06<1:24:41,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 277/984 [33:14<1:24:23,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 278/984 [33:21<1:24:18,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 279/984 [33:28<1:24:23,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  28%|██▊       | 280/984 [33:35<1:24:04,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▊       | 281/984 [33:42<1:24:02,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▊       | 282/984 [33:49<1:23:56,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 283/984 [33:57<1:23:50,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 284/984 [34:04<1:23:41,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 285/984 [34:11<1:23:25,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 286/984 [34:18<1:23:36,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 287/984 [34:25<1:23:41,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 288/984 [34:33<1:23:27,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 289/984 [34:40<1:23:15,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  29%|██▉       | 290/984 [34:47<1:23:13,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|██▉       | 291/984 [34:54<1:23:07,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|██▉       | 292/984 [35:01<1:23:00,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|██▉       | 293/984 [35:09<1:22:47,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|██▉       | 294/984 [35:16<1:23:17,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|██▉       | 295/984 [35:23<1:22:58,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|███       | 296/984 [35:31<1:23:37,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|███       | 297/984 [35:38<1:23:03,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|███       | 298/984 [35:45<1:23:03,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|███       | 299/984 [35:52<1:22:38,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  30%|███       | 300/984 [35:59<1:22:44,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 301/984 [36:07<1:22:29,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 302/984 [36:14<1:22:14,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 303/984 [36:21<1:21:47,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 304/984 [36:25<1:12:08,  6.36s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 305/984 [36:33<1:15:14,  6.65s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 306/984 [36:40<1:16:54,  6.81s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███       | 307/984 [36:47<1:18:31,  6.96s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███▏      | 308/984 [36:54<1:19:20,  7.04s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  31%|███▏      | 309/984 [37:02<1:20:22,  7.14s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 310/984 [37:09<1:20:33,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 311/984 [37:16<1:20:32,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 312/984 [37:24<1:20:41,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 313/984 [37:31<1:20:27,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 314/984 [37:38<1:20:52,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 315/984 [37:45<1:20:31,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 316/984 [37:52<1:20:16,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 317/984 [38:00<1:20:21,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 318/984 [38:07<1:20:02,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  32%|███▏      | 319/984 [38:14<1:20:05,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 320/984 [38:21<1:19:54,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 321/984 [38:29<1:19:52,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 322/984 [38:36<1:19:39,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 323/984 [38:43<1:19:28,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 324/984 [38:50<1:19:17,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 325/984 [38:57<1:19:03,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 326/984 [39:05<1:18:56,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 327/984 [39:12<1:19:45,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 328/984 [39:19<1:19:11,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  33%|███▎      | 329/984 [39:26<1:18:47,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▎      | 330/984 [39:34<1:18:32,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▎      | 331/984 [39:41<1:18:18,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▎      | 332/984 [39:48<1:18:07,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 333/984 [39:55<1:18:04,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 334/984 [40:02<1:17:51,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 335/984 [40:09<1:17:41,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 336/984 [40:17<1:18:04,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 337/984 [40:24<1:17:55,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 338/984 [40:31<1:17:39,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  34%|███▍      | 339/984 [40:38<1:17:25,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▍      | 340/984 [40:46<1:17:22,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▍      | 341/984 [40:53<1:17:15,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▍      | 342/984 [41:00<1:17:05,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▍      | 343/984 [41:07<1:17:10,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▍      | 344/984 [41:14<1:16:56,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▌      | 345/984 [41:22<1:16:45,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▌      | 346/984 [41:29<1:16:35,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▌      | 347/984 [41:36<1:16:22,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▌      | 348/984 [41:43<1:16:11,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  35%|███▌      | 349/984 [41:50<1:15:58,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 350/984 [41:58<1:15:50,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 351/984 [42:05<1:15:53,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 352/984 [42:12<1:15:42,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 353/984 [42:19<1:16:05,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 354/984 [42:27<1:16:06,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 355/984 [42:34<1:16:13,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▌      | 356/984 [42:41<1:15:59,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▋      | 357/984 [42:48<1:15:45,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▋      | 358/984 [42:56<1:15:41,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  36%|███▋      | 359/984 [43:03<1:16:09,  7.31s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 360/984 [43:10<1:15:41,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 361/984 [43:18<1:15:38,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 362/984 [43:25<1:15:30,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 363/984 [43:32<1:15:43,  7.32s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 364/984 [43:39<1:15:21,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 365/984 [43:47<1:14:58,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 366/984 [43:54<1:15:04,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 367/984 [44:01<1:15:05,  7.30s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  37%|███▋      | 368/984 [44:09<1:14:53,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 369/984 [44:16<1:14:39,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 370/984 [44:23<1:14:25,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 371/984 [44:30<1:14:06,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 372/984 [44:38<1:13:53,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 373/984 [44:45<1:13:39,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 374/984 [44:52<1:13:18,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 375/984 [44:59<1:13:03,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 376/984 [45:06<1:12:53,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 377/984 [45:14<1:12:58,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  38%|███▊      | 378/984 [45:21<1:12:47,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▊      | 379/984 [45:28<1:12:30,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▊      | 380/984 [45:32<1:03:39,  6.32s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▊      | 381/984 [45:39<1:06:13,  6.59s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▉      | 382/984 [45:47<1:07:56,  6.77s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▉      | 383/984 [45:54<1:09:00,  6.89s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▉      | 384/984 [46:01<1:09:42,  6.97s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▉      | 385/984 [46:08<1:10:08,  7.03s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▉      | 386/984 [46:15<1:10:40,  7.09s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  39%|███▉      | 387/984 [46:22<1:10:45,  7.11s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
# ...
#  87%|████████▋ | 856/984 [1:42:38<15:24,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  87%|████████▋ | 857/984 [1:42:45<15:18,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  87%|████████▋ | 858/984 [1:42:52<15:10,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  87%|████████▋ | 859/984 [1:42:59<15:01,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  87%|████████▋ | 860/984 [1:43:06<14:52,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 861/984 [1:43:14<14:44,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 862/984 [1:43:21<14:36,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 863/984 [1:43:28<14:29,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 864/984 [1:43:35<14:21,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 865/984 [1:43:42<14:13,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 866/984 [1:43:49<14:05,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 867/984 [1:43:57<14:01,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 868/984 [1:44:02<12:49,  6.64s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 869/984 [1:44:09<13:03,  6.82s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  88%|████████▊ | 870/984 [1:44:16<13:09,  6.92s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▊ | 871/984 [1:44:24<13:10,  7.00s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▊ | 872/984 [1:44:31<13:09,  7.05s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▊ | 873/984 [1:44:38<13:09,  7.12s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 874/984 [1:44:45<13:07,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 875/984 [1:44:53<13:03,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 876/984 [1:45:00<12:55,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 877/984 [1:45:07<12:47,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 878/984 [1:45:14<12:41,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 879/984 [1:45:21<12:33,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  89%|████████▉ | 880/984 [1:45:28<12:25,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|████████▉ | 881/984 [1:45:36<12:20,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|████████▉ | 882/984 [1:45:43<12:13,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|████████▉ | 883/984 [1:45:50<12:04,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|████████▉ | 884/984 [1:45:57<11:57,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|████████▉ | 885/984 [1:46:04<11:49,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|█████████ | 886/984 [1:46:11<11:41,  7.16s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|█████████ | 887/984 [1:46:18<11:33,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|█████████ | 888/984 [1:46:26<11:26,  7.15s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|█████████ | 889/984 [1:46:33<11:22,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  90%|█████████ | 890/984 [1:46:40<11:17,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 891/984 [1:46:48<11:17,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 892/984 [1:46:55<11:07,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 893/984 [1:47:02<10:58,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 894/984 [1:47:09<10:48,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 895/984 [1:47:16<10:40,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 896/984 [1:47:24<10:37,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████ | 897/984 [1:47:31<10:27,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████▏| 898/984 [1:47:38<10:19,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████▏| 899/984 [1:47:45<10:13,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  91%|█████████▏| 900/984 [1:47:52<10:06,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 901/984 [1:48:00<09:57,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 902/984 [1:48:07<09:51,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 903/984 [1:48:14<09:44,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 904/984 [1:48:21<09:36,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 905/984 [1:48:29<09:33,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 906/984 [1:48:36<09:23,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 907/984 [1:48:43<09:19,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 908/984 [1:48:50<09:10,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 909/984 [1:48:58<09:02,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  92%|█████████▏| 910/984 [1:49:05<08:54,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 911/984 [1:49:12<08:47,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 912/984 [1:49:19<08:38,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 913/984 [1:49:26<08:31,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 914/984 [1:49:34<08:23,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 915/984 [1:49:41<08:16,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 916/984 [1:49:48<08:10,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 917/984 [1:49:55<08:05,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 918/984 [1:50:02<07:56,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 919/984 [1:50:10<07:48,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  93%|█████████▎| 920/984 [1:50:17<07:40,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▎| 921/984 [1:50:24<07:32,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▎| 922/984 [1:50:31<07:26,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 923/984 [1:50:38<07:19,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 924/984 [1:50:46<07:11,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 925/984 [1:50:53<07:04,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 926/984 [1:51:00<06:57,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 927/984 [1:51:07<06:51,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 928/984 [1:51:14<06:44,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  94%|█████████▍| 929/984 [1:51:22<06:36,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▍| 930/984 [1:51:29<06:30,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▍| 931/984 [1:51:36<06:24,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▍| 932/984 [1:51:43<06:15,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▍| 933/984 [1:51:51<06:07,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▍| 934/984 [1:51:58<05:59,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▌| 935/984 [1:52:05<05:53,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▌| 936/984 [1:52:12<05:46,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▌| 937/984 [1:52:19<05:38,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▌| 938/984 [1:52:26<05:30,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  95%|█████████▌| 939/984 [1:52:34<05:22,  7.17s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 940/984 [1:52:41<05:17,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 941/984 [1:52:48<05:11,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 942/984 [1:52:55<05:03,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 943/984 [1:53:03<04:58,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 944/984 [1:53:10<04:51,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 945/984 [1:53:18<04:45,  7.31s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 946/984 [1:53:25<04:35,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▌| 947/984 [1:53:32<04:27,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▋| 948/984 [1:53:39<04:20,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  96%|█████████▋| 949/984 [1:53:46<04:12,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 950/984 [1:53:53<04:05,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 951/984 [1:54:01<03:58,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 952/984 [1:54:08<03:51,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 953/984 [1:54:15<03:44,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 954/984 [1:54:22<03:36,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 955/984 [1:54:30<03:28,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 956/984 [1:54:37<03:21,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 957/984 [1:54:44<03:17,  7.30s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 958/984 [1:54:52<03:10,  7.31s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  97%|█████████▋| 959/984 [1:54:59<03:01,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 960/984 [1:55:06<02:54,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 961/984 [1:55:13<02:46,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 962/984 [1:55:21<02:39,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 963/984 [1:55:28<02:31,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 964/984 [1:55:35<02:24,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 965/984 [1:55:42<02:18,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 966/984 [1:55:50<02:10,  7.27s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 967/984 [1:55:57<02:03,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 968/984 [1:56:04<01:55,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  98%|█████████▊| 969/984 [1:56:11<01:48,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▊| 970/984 [1:56:19<01:42,  7.29s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▊| 971/984 [1:56:26<01:34,  7.28s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 972/984 [1:56:33<01:27,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 973/984 [1:56:40<01:19,  7.25s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 974/984 [1:56:47<01:12,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 975/984 [1:56:55<01:04,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 976/984 [1:57:02<00:57,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 977/984 [1:57:09<00:50,  7.19s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 978/984 [1:57:16<00:43,  7.23s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
#  99%|█████████▉| 979/984 [1:57:24<00:36,  7.24s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
# 100%|█████████▉| 980/984 [1:57:31<00:28,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
# 100%|█████████▉| 981/984 [1:57:38<00:21,  7.20s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
# 100%|█████████▉| 982/984 [1:57:45<00:14,  7.22s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
# 100%|█████████▉| 983/984 [1:57:52<00:07,  7.21s/it]Setting `pad_token_id` to `eos_token_id`:128009 for open-end generation.
# 100%|██████████| 984/984 [1:58:00<00:00,  7.20s/it]
# 结果已保存到 RAG_diagnosis_predictions_V2.csv

# %%
import pandas as pd
import numpy as np
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
from fuzzywuzzy import fuzz
import re

def compute_rouge(refs, preds):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
    rouge1, rougel = [], []
    for ref, pred in zip(refs, preds):
        scores = scorer.score(ref, pred)
        rouge1.append(scores['rouge1'].fmeasure)
        rougel.append(scores['rougeL'].fmeasure)
    return np.mean(rouge1), np.mean(rougel)

def compute_avg_meteor(refs, preds, verbose=True):
    scores = []
    for i, (ref, pred) in enumerate(zip(refs, preds)):
        score = meteor_score([ref.split()], pred.split())
        scores.append(score)        
        # if verbose:
        #     print(f"[{i}]")
        #     print(f"GT   : {ref}")
        #     print(f"PRED : {pred}")
        #     print(f"METEOR : {score:.4f}")
        #     print("-" * 40)
    return np.mean(scores)

def compute_fuzzy_accuracy(refs, preds, threshold=80):
    matches = [fuzz.partial_ratio(ref.lower(), pred.lower()) >= threshold for ref, pred in zip(refs, preds)]
    return sum(matches) / len(matches)


df = pd.read_csv("RAG_diagnosis_predictions_V2.csv")
# gt_list = df["ground_truth"].astype(str).tolist()
gt_list = df["ground_truth"].astype(str).str.strip().str.lower().tolist()


def clean_prediction(pred):
    match = re.search(r"Diagnosis:\s*(.+)", pred, re.IGNORECASE)
    if match:
        diagnosis_text = match.group(1).strip()

        advice_idx = diagnosis_text.lower().find(". advice:")
        if advice_idx != -1:
            diagnosis_text = diagnosis_text[:advice_idx]

        diagnosis_first_line = re.split(r"\s*\n", diagnosis_text)[0].strip()
        return diagnosis_first_line.lower()
    else:
        return pred.strip().lower()

pred_list = df["extracted_diagnosis"].astype(str).apply(clean_prediction).tolist()

r1, rl = compute_rouge(gt_list, pred_list)
meteor = compute_avg_meteor(gt_list, pred_list)
fuzzy_acc = compute_fuzzy_accuracy(gt_list, pred_list)

print(f"ROUGE-1 F1: {r1:.2f}")
print(f"ROUGE-L F1: {rl:.2f}")
print(f"METEOR Score: {meteor:.2f}")
print(f"Fuzzy Matching Accuracy: {fuzzy_acc * 100:.2f}%")
# Out:
# ROUGE-1 F1: 0.92
# ROUGE-L F1: 0.92
# METEOR Score: 0.65
# Fuzzy Matching Accuracy: 95.83%

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def compute_avg_bleu(refs, preds, verbose=True):
    smoothie = SmoothingFunction().method4
    bleu_scores = []

    for i, (ref, pred) in enumerate(zip(refs, preds)):
        ref_tokens = ref.split()
        pred_tokens = pred.split()
        bleu = sentence_bleu([ref_tokens], pred_tokens, weights=(1, 0, 0, 0), smoothing_function=smoothie)
        bleu_scores.append(bleu)
        
        # if verbose:
        #     print(f"[{i}]")
        #     print(f"GT   : {ref}")
        #     print(f"PRED : {pred}")
        #     print(f"BLEU : {bleu:.4f}")
        #     print("-" * 40)

    return np.mean(bleu_scores)

bleu = compute_avg_bleu(gt_list, pred_list)
print(f"BLEU Score: {bleu:.2f}")
# Out:
# BLEU Score: 0.91
